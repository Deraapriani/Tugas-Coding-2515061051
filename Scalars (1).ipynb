# %% [markdown]
# Scalars

# %%
# buat variabel skalar x dan simpan suatu nilai skalar
x = 51
x
# Out:
# 51

# %%
# tampilkan tipe data dari x
type(x)
# Out:
# int

# %%
# buat variabel skalar y dan simpan suatu nilai skalar
y = 86
y
# Out:
# 86

# %%
# tampilkan tipe data dari y
type(y)
# Out:
# int

# %%
#  jumlahkan x+y
py_sum = x + y
py_sum
# Out:
# 137

# %%
type(py_sum)
type(py_sum)
# Out:
# int

# %%
# buat variabel bernama x_float dan simpan suatu nilai desimal
x_float = 0.51

# %%
# jumlahkan x_float dengan y
float_sum = x_float + y
float_sum
# Out:
# 86.51

# %%
# tampilkan tipe data dari x_float
type(x_float)
# Out:
# float

# %% [markdown]
# TensorFlow

# %%
import tensorflow as tf

# %%
# lakukan pada tahapan soal 1 dengan tensorflow
x_tf = tf.Variable(51.0)
print (x_tf)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=51.0>

# %%
y_tf2 = tf.Variable(0.51)

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(86)
print(f"variabel tensor y adalah :", y_tf)
# Out:
# variabel tensor y adalah : <tf.Variable 'Variable:0' shape=() dtype=int32, numpy=86>

# %%
x_tf = y_tf
print(f"hasil penjumlahan dari x dan y adalah :", x_tf + y_tf)
# Out:
# hasil penjumlahan dari x dan y adalah : tf.Tensor(172, shape=(), dtype=int32)

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
print(f"hasil penjumlahan dari x dan y adalah :", tf_sum)
# Out:
# hasil penjumlahan dari x dan y adalah : tf.Tensor(172, shape=(), dtype=int32)

# %%
tf_sum.numpy()
print(f"hasil penjumlahan dari x dan y adalah :", tf_sum.numpy())
# Out:
# hasil penjumlahan dari x dan y adalah : 172

# %%
type(tf_sum.numpy())
# Out:
# numpy.int32

# %%
tf_float = tf.Variable(51.)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=51.0>

# %% [markdown]
# Pytorch

# %%
import torch

# %%
x_pt = torch.tensor(51) # type specification optional, e.g.: dtype=torch.float16
x_pt
# Out:
# tensor(51)

# %%
x_pt.shape
print("ukuran x_pt: ", x_pt.shape)
# Out:
# ukuran x_pt:  torch.Size([])
