# %% [markdown]
# Norms

# %%
import numpy as np

# %%
# Membuat vektor x
x = np.array([30, 6, 8])
x
# Out:
# array([30,  6,  8])

# %%
# Menghitung L2 Norm (Panjang Vektor)
(30**2 + 6**2 + 8**2)**(1/2)
# Out:
# 31.622776601683793

# %%
np.linalg.norm(x)
# Out:
# np.float64(31.622776601683793)

# %% [markdown]
# Unit Vectors

# %%
# Membuat vektor
v = np.array([3, 4])

# Menghitung L2 Norm (Panjang Vektor)
norm = np.linalg.norm(v)

# Menghitung unit vector
unit_v = v / norm

# tampilkan unit vector dari vector v

print("Vektor asli:", v)
print("Panjang vektor:", norm)
print("Unit vector:", unit_v)
print("Panjang unit vector:", np.linalg.norm(unit_v))
# Out:
# Vektor asli: [3 4]
# Panjang vektor: 5.0
# Unit vector: [0.6 0.8]
# Panjang unit vector: 1.0
